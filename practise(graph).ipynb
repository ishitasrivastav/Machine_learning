# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
a=pd.read_csv('assignment 2/Casuality_details.csv')
a
# Out:
#        Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0            2.02E+12                  2                   1               1
# 1            2.02E+12                  1                   1               1
# 2            2.02E+12                  1                   1               1
# 3            2.02E+12                  1                   1               2
# 4            2.02E+12                  2                   1               1
# ...               ...                ...                 ...             ...
# 181379       2.02E+12                  1                   1               1
# 181380       2.02E+12                  1                   2               2
# 181381       2.02E+12                  1                   3               2
# 181382       2.02E+12                  1                   1               1
# 181383       2.02E+12                  1                   2               2
#
# ...

# %%
b=pd.read_csv('assignment 2/MakeModel2016.csv')
b
# Out:
#        Accident_Index  accyr  Vehicle_Reference  Vehicle_Type  \
# 0       2016010000005   2016                  1             8
# 1       2016010000005   2016                  2             2
# 2       2016010000006   2016                  1             9
# 3       2016010000008   2016                  1             9
# 4       2016010000016   2016                  1            11
# ...               ...    ...                ...           ...
# 252495  2016984131116   2016                  1             9
# 252496  2016984131116   2016                  2             9
# 252497  2016984131216   2016                  1            21
# 252498  2016984131316   2016                  1             9
# 252499  2016984133416   2016                  1             9
#
#         Towing_and_Articulation  Vehicle_Manoeuvre  \
# 0                             0                  6
# 1                             0                 18
# 2                             0                 18
# ...

# %%
c=pd.read_csv('assignment 2/Vehicle_details.csv')
c
# Out:
# C:\Users\ishit\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        Accident_Index  Vehicle_Reference  Vehicle_Type  \
# 0            2.02E+12                  1             8
# 1            2.02E+12                  2             2
# 2            2.02E+12                  1             9
# 3            2.02E+12                  1             9
# 4            2.02E+12                  1            11
# ...               ...                ...           ...
# 133038       2.02e+12                  1             5
# 133039       2.02e+12                  2             9
# 133040       2.02e+12                  3            21
# 133041       2.02e+12                  1            21
# 133042       2.02e+12                  2             9
#
#         Towing_and_Articulation  Vehicle_Manoeuvre  \
# ...

# %%
a['Sex_of_Casualty'].value_counts()
# Out:
#  1    107556
#  2     73776
# -1        52
# Name: Sex_of_Casualty, dtype: int64

# %%
#q1
q=a.Sex_of_Casualty.value_counts().plot(kind='bar')

# %%
d=pd.read_csv('assignment 2/Accidents_2016.csv')
d
# Out:
# C:\Users\ishit\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (31) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0            2.02E+12               519310.0                188730.0
# 1            2.02E+12               551920.0                174560.0
# 2            2.02E+12               505930.0                183850.0
# 3            2.02E+12               527770.0                168930.0
# 4            2.02E+12               510740.0                177230.0
# ...               ...                    ...                     ...
# 136616       2.02E+12               319273.0                574564.0
# 136617       2.02E+12               316143.0                568615.0
# 136618       2.02E+12               322903.0                573365.0
# ...

# %%
df=pd.merge(a,b,on='Accident_Index',how='inner')
df
# Out:
#        Accident_Index  Vehicle_Reference_x  Casualty_Reference  \
# 0       2016010X31538                    2                   1
# 1       2016010X31538                    2                   1
# 2       2016010X31762                    1                   1
# 3       2016010X31762                    1                   1
# 4       2016010X31762                    1                   2
# ...               ...                  ...                 ...
# 104370  201697UD71308                    1                   1
# 104371  201697UD71308                    1                   1
# 104372  201697UD71408                    2                   1
# 104373  201697UD71408                    2                   1
# 104374  201697UD71408                    2                   1
#
#         Casualty_Class  Sex_of_Casualty  Age_of_Casualty  \
# 0                    1                1               25
# 1                    1                1               25
# ...

# %%
df1=pd.merge(df,c,on='Accident_Index',how='inner')
df1
# Out:
#        Accident_Index  Vehicle_Reference_x  Casualty_Reference  \
# 0       2016010X31538                    2                   1
# 1       2016010X31538                    2                   1
# 2       2016010X31538                    2                   1
# 3       2016010X31538                    2                   1
# 4       2016010X31762                    1                   1
# ...               ...                  ...                 ...
# 158884  201631P278316                    2                   1
# 158885  201631P278316                    2                   2
# 158886  201631P278316                    2                   2
# 158887  201631P278316                    2                   2
# 158888  201631P278316                    2                   2
#
#         Casualty_Class  Sex_of_Casualty  Age_of_Casualty  \
# 0                    1                1               25
# 1                    1                1               25
# ...

# %%
df2=pd.merge(df1,d,on='Accident_Index',how='inner')
df2
# Out:
#        Accident_Index  Vehicle_Reference_x  Casualty_Reference  \
# 0       2016010X31538                    2                   1
# 1       2016010X31538                    2                   1
# 2       2016010X31538                    2                   1
# 3       2016010X31538                    2                   1
# 4       2016010X31762                    1                   1
# ...               ...                  ...                 ...
# 158884  201631P278316                    2                   1
# 158885  201631P278316                    2                   2
# 158886  201631P278316                    2                   2
# 158887  201631P278316                    2                   2
# 158888  201631P278316                    2                   2
#
#         Casualty_Class  Sex_of_Casualty  Age_of_Casualty  \
# 0                    1                1               25
# 1                    1                1               25
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158889 entries, 0 to 158888
# Data columns (total 92 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Accident_Index                               158889 non-null  object
#  1   Vehicle_Reference_x                          158889 non-null  int64
#  2   Casualty_Reference                           158889 non-null  int64
#  3   Casualty_Class                               158889 non-null  int64
#  4   Sex_of_Casualty                              158889 non-null  int64
#  5   Age_of_Casualty                              158889 non-null  int64
#  6   Age_Band_of_Casualty                         158889 non-null  int64
#  7   Casualty_Severity                            158889 non-null  int64
#  8   Pedestrian_Location                          158889 non-null  int64
# ...

# %%
#q2
df2['Time'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#q3:
df2['Time'].value_counts().sort_values(ascending=True).head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
k=df2[(df2['Vehicle_Type_x']==8)|(df2['Vehicle_Type_x']==9)]
k
k['Vehicle_Type_x'].value_counts()
# Out:
# 9    115242
# 8      5115
# Name: Vehicle_Type_x, dtype: int64

# %%
k['model'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
k['make'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
l=df2[(df2['Accident_Severity']==1)|(df2['Accident_Severity']==2)|(df2['Accident_Severity']==3)]
l
l['Accident_Severity'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Accident_Severity'>

# %%
#q6
m=df2[(df2['Accident_Severity']==1)]
m
m['Road_Surface_Conditions'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#q7
n=df2[(df2['Vehicle_Type_x']==1)]
n
n['Vehicle_Type_x'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#q8
df2['Light_Conditions'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(df2['Weather_Conditions'],label='count')
plt.show()
# Out:
# C:\Users\ishit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#q10
k['model'].value_counts().head(1)
# Out:
# FIESTA ZETEC    1029
# Name: model, dtype: int64

# %%
a=b=c=d=e=f=g=h=k=''
def design():
    global a,b,c,d,e,f,g,h,k
 
    print("\t\t\t\t |\t\t|")
    print("\t\t\t    %s    |     %s         |  %s  "%(a,b,c))
    print("\t\t\t\t |\t\t|")
    print("\t\t\t",'='*30)
    print("\t\t\t\t |\t\t|")
    print("\t\t\t    %s     |     %s         |  %s  "%(d,e,f))
    print("\t\t\t\t |\t\t|")
    print("\t\t\t",'='*30)
    print("\t\t\t\t |\t\t|")
    print("\t\t\t    %s     |     %s         |  %s  "%(g,h,k))
    print("\t\t\t\t |\t\t|")


print("press a to enter the first opsition")
print("press b to enter the second opsition")
print("press c to enter the third opsition")
print("press d to enter the fourth opsition")
print("press e to enter the fifth opsition")
print("press f to enter the sixth opsition")
print("press g to enter the seven opsition")
print("press h to enter the eight opsition")
print("press i to enter the nineth opsition")




def winner():
    if(a=='x' and b=='x' and c=='x'):
        print("x is winner")
    elif(a=='x' and d=='x' and g=='x'):
        print("x is winner")
    elif(b=='x' and e=='x' and h=='x'):
        print("x is winner")
    elif(c=='x' and f=='x' and k=='x'):
        print("x is winner")
    elif(d=='x' and e=='x' and f=='x'):
        print("x is winner")
    elif(g=='x' and h=='x' and k=='x'):
        print("x is winner")
    elif(a=='x' and e=='x' and k=='x'):
        print("x is winner")
    elif(c=='x' and e=='x' and g=='x'):
        print("x is winner")
        
    elif(a=='0' and b=='0' and c=='0'):
        print("0 is winner")
    elif(a=='0' and d=='0' and g=='0'):
        print("0 is winner")
    elif(b=='0' and e=='0' and h=='0'):
        print("0 is winner")
    elif(c=='0' and f=='0' and k=='0'):
        print("0 is winner")
    elif(d=='0' and e=='0' and f=='0'):
        print("0 is winner")
    elif(g=='0' and h=='0' and k=='0'):
        print("0 is winner")
    elif(a=='0' and e=='0' and k=='0'):
        print("0 is winner")
    elif(c=='0' and e=='0' and g=='0'):
        print("0 is winner")
        
    






for i in range(1,10):
    z=str(input("enter the position="))
    if(z=='a'):
        a=input("enter '0' or 'x'")
        design()
        winner()


    if(z=='b'):
        b=input("enter '0' or 'x'")
        design()
        winner()
    if(z=='c'):
        c=input("enter '0' or 'x'")
        design()
        winner()
    


    if(z=='d'):
        d=input("enter '0' or 'x'")
        design()
        winner()
    if(z=='e'):
        e=input("enter '0' or 'x'")
        design()
        winner()
    if(z=='f'):
        f=input("enter '0' or 'x'")
        design()
        winner()
    
    if(z=='g'):
        g=input("enter '0' or 'x'")
        design()
        winner()
    if(z=='h'):
        h=input("enter '0' or 'x'")
        design()
        winner()
    if(z=='k'):
        k=input("enter '0' or 'x'")
        design()
        winner()

 
else:
    print('tie')
